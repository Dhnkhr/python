# %%
import pandas as pd

# %%
data = pd.read_csv('xyz.csv')

# %%
data.describe()
# Out:
#        CustomerId   TotalSpent
# count    10.00000    10.000000
# mean   1005.50000   580.699000
# std       3.02765   680.961007
# min    1001.00000     0.000000
# 25%    1003.25000    79.122500
# 50%    1005.50000   385.125000
# 75%    1007.75000   870.187500
# max    1010.00000  2100.000000

# %%
data.isnull()
# Out:
#    CustomerId  FirstName  LastName  Email  JoinDate  TotalSpent  Status
# 0       False      False     False  False     False       False   False
# 1       False      False     False  False     False       False   False
# 2       False      False     False  False     False       False   False
# 3       False      False     False  False     False       False   False
# 4       False      False     False  False     False       False   False
# 5       False      False     False  False     False       False   False
# 6       False      False     False  False     False       False   False
# 7       False      False     False  False     False       False   False
# 8       False      False     False  False     False       False   False
# 9       False      False     False  False     False       False   False

# %%
data.isnull().any(axis=1)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
data.isnull().any()
# Out:
# CustomerId    False
# FirstName     False
# LastName      False
# Email         False
# JoinDate      False
# TotalSpent    False
# Status        False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# CustomerId    0
# FirstName     0
# LastName      0
# Email         0
# JoinDate      0
# TotalSpent    0
# Status        0
# dtype: int64

# %%
data.fillna(0)
# Out:
#    CustomerId FirstName   LastName                 Email    JoinDate  \
# 0        1001      Liam     Conner    liam.c@example.com  2025-01-15
# 1        1002    Olivia   Martinez  olivia.m@example.com  2025-02-18
# 2        1003     Ethan     Brooks   ebrooks@example.com  2025-03-02
# 3        1004    Sophia       Yang  sophia.y@example.com  2025-05-12
# 4        1005   Jackson       Tate     jtate@example.com  2025-06-20
# 5        1006      Emma      Smith    emma.s@example.com  2025-07-11
# 6        1007     Lucas      Davis   lucas.d@example.com  2025-08-30
# 7        1008       Ava      Brown     ava.b@example.com  2025-09-05
# 8        1009       Mia     Garcia     mia.g@example.com  2025-10-22
# 9        1010    Oliver  Rodriguez  oliver.r@example.com  2025-11-14
#
#    TotalSpent    Status
# 0      450.25    Active
# 1       89.99    Active
# 2        0.00  Inactive
# 3     1250.50   Premium
# 4      320.00    Active
# 5       75.50    Active
# 6     2100.00   Premium
# ...

# %%
data['CustomerId_fillna']=data['CustomerId'].fillna(data['CustomerId'].mean())

# %%
data
# Out:
#    CustomerId FirstName   LastName                 Email    JoinDate  \
# 0        1001      Liam     Conner    liam.c@example.com  2025-01-15
# 1        1002    Olivia   Martinez  olivia.m@example.com  2025-02-18
# 2        1003     Ethan     Brooks   ebrooks@example.com  2025-03-02
# 3        1004    Sophia       Yang  sophia.y@example.com  2025-05-12
# 4        1005   Jackson       Tate     jtate@example.com  2025-06-20
# 5        1006      Emma      Smith    emma.s@example.com  2025-07-11
# 6        1007     Lucas      Davis   lucas.d@example.com  2025-08-30
# 7        1008       Ava      Brown     ava.b@example.com  2025-09-05
# 8        1009       Mia     Garcia     mia.g@example.com  2025-10-22
# 9        1010    Oliver  Rodriguez  oliver.r@example.com  2025-11-14
#
#    TotalSpent    Status  CustomerId_fillna
# 0      450.25    Active               1001
# 1       89.99    Active               1002
# 2        0.00  Inactive               1003
# ...

# %%
data['value_new']=data['CustomerId'].astype(float)

# %%
data
# Out:
#    CustomerId FirstName   LastName                 Email    JoinDate  \
# 0        1001      Liam     Conner    liam.c@example.com  2025-01-15
# 1        1002    Olivia   Martinez  olivia.m@example.com  2025-02-18
# 2        1003     Ethan     Brooks   ebrooks@example.com  2025-03-02
# 3        1004    Sophia       Yang  sophia.y@example.com  2025-05-12
# 4        1005   Jackson       Tate     jtate@example.com  2025-06-20
# 5        1006      Emma      Smith    emma.s@example.com  2025-07-11
# 6        1007     Lucas      Davis   lucas.d@example.com  2025-08-30
# 7        1008       Ava      Brown     ava.b@example.com  2025-09-05
# 8        1009       Mia     Garcia     mia.g@example.com  2025-10-22
# 9        1010    Oliver  Rodriguez  oliver.r@example.com  2025-11-14
#
#    TotalSpent    Status  CustomerId_fillna  value_new
# 0      450.25    Active               1001     1001.0
# 1       89.99    Active               1002     1002.0
# ...

# %%
data['new_val']=data['CustomerId'].apply(lambda X: X*2)

# %%
data
# Out:
#    CustomerId FirstName   LastName                 Email    JoinDate  \
# 0        1001      Liam     Conner    liam.c@example.com  2025-01-15
# 1        1002    Olivia   Martinez  olivia.m@example.com  2025-02-18
# 2        1003     Ethan     Brooks   ebrooks@example.com  2025-03-02
# 3        1004    Sophia       Yang  sophia.y@example.com  2025-05-12
# 4        1005   Jackson       Tate     jtate@example.com  2025-06-20
# 5        1006      Emma      Smith    emma.s@example.com  2025-07-11
# 6        1007     Lucas      Davis   lucas.d@example.com  2025-08-30
# 7        1008       Ava      Brown     ava.b@example.com  2025-09-05
# 8        1009       Mia     Garcia     mia.g@example.com  2025-10-22
# 9        1010    Oliver  Rodriguez  oliver.r@example.com  2025-11-14
#
#    TotalSpent    Status  CustomerId_fillna  value_new  new_val
# 0      450.25    Active               1001     1001.0     2002
# 1       89.99    Active               1002     1002.0     2004
# ...

# %%
grpd_add=data.groupby('CustomerId')['value_new'].agg(['mean','sum','count'])

# %%
grpd_add
# Out:
#               mean     sum  count
# CustomerId
# 1001        1001.0  1001.0      1
# 1002        1002.0  1002.0      1
# 1003        1003.0  1003.0      1
# 1004        1004.0  1004.0      1
# 1005        1005.0  1005.0      1
# 1006        1006.0  1006.0      1
# 1007        1007.0  1007.0      1
# 1008        1008.0  1008.0      1
# 1009        1009.0  1009.0      1
# 1010        1010.0  1010.0      1
