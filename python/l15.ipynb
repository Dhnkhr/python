# %%
class Person:
    def __init__(self,name,age,gender):
        self.__name=name
        self.__age=age
        self.gender=gender

class Employee(Person):
    def __init__(self,name,age,gender):
        super().__init__(name,age.gender)

def get_name(person):
    return person._Person__name

person=Person("Abc",20,"M")
person1=Person("Abd",20,"M")
get_name(person)
get_name(person1)
# Out:
# 'Abc'
