# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
print(22/7-math.pi)
# Out:
# 0.0012644892673496777

# %%
import numpy as np

# %%
np.array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
from math import *
