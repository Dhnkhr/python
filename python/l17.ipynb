# %%
my=[1,2,3,4,5,6]
print(type(my))
# Out:
# <class 'list'>

# %%
iterator=iter(my)

# %%
next(iterator)
# Out:
# 1

# %%
def square(n):
    for i in range(3):
        yield i**2

square(3)
# Out:
# <generator object square at 0x0000023C0D934D40>

# %%
for i in square(3):
    print(i)
# Out:
# 0
# 1
# 4

# %%
def welcome():
    return "welcome!"

wel=welcome

# %%
print(wel())
# Out:
# welcome!

# %%
def main_welcome(func,lst):
    msg="welcome"
    def sub_welcome_method():
        func
       ## print(func(lst))
        print("welcome tro the arena")
    return sub_welcome_method()

# %%
main_welcome(len,[1,2,3,4,5])
# Out:
# 5
# welcome tro the arena

# %%
def main_wel(func):
    msg="welcome"
    def sub_welcome_method():
        func()
        print("welcome to the arena")
    return sub_welcome_method()

@main_wel
def say():
    print("hello")
# Out:
# hello
# welcome to the arena
