# %%
age = 32
name = "adi"
height = 5.9
is_student = True 

print(age)
# Out:
# 32

# %%
#type_conversion
age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# 32
# <class 'str'>

# %%
height=5.11
int(height)
# Out:
# 5

# %%
float(int(height))
# Out:
# 5.0

# %%
##dynamic typing
var=10
print(var,type(var))

var="hello"
print(var,type(var))
# Out:
# 10 <class 'int'>
# hello <class 'str'>
