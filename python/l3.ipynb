# %%
hi="hi"
print(hi)
# Out:
# hi

# %%
#floor division
a=10
b=5

a//b

##exponent result
expo=a**b
 
print(expo)
# Out:
# 100000

# %%
age = 2

if age>=20:
    print(age)
else:
    print("minor")
# Out:
# minor

# %%
age>=5
# Out:
# False

# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(1,6,2):
    print(i)
# Out:
# 1
# 3
# 5

# %%
for i in range(10,1,-1):
    print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
for i in range(10,1,-2):
    print(i)
# Out:
# 10
# 8
# 6
# 4
# 2

# %%
str = "My name is Adi"

for i in str:
    print(i)
# Out:
# M
# y
#
# n
# a
# m
# e
#
# i
# s
#
# A
# d
# i

# %%
count=0
while count<5:
    print(count)
    count+=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(10):
    if i%2==0:
        continue
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(3):
    for j in range(5):
        print(f"i:{i} and j:{j}")
# Out:
# i:0 and j:0
# i:0 and j:1
# i:0 and j:2
# i:0 and j:3
# i:0 and j:4
# i:1 and j:0
# i:1 and j:1
# i:1 and j:2
# i:1 and j:3
# i:1 and j:4
# i:2 and j:0
# i:2 and j:1
# i:2 and j:2
# i:2 and j:3
# i:2 and j:4
