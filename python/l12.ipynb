# %%
with open('example.txt', 'r') as file:
    content=file.read()
    print(content)
# Out:
# hello

# %%
with open('example.txt','r') as file:
    for line in file:
        print(line.strip())  ## strip remove the newline character
# Out:
# hello
# how r u?
# i m fine

# %%
with open('example.txt','a') as file:
    file.write("this write without overwritting the previous one")

# %%
data = b'\x00\x01\x02\x03\x04'
with open('example.bin', 'wb') as file:
    file.write(data)

# %%
with open('example.txt','w+') as file:
    file.write("hello world\n")
    file.write("this is again a new line")

    file.seek(0)
    content=file.read()
    print(content)
# Out:
# hello world
# this is again a new line

# %%
import os
dir_name="folder"
file_name="file.txt"
ful_path=os.path.join(os.getcwd(),dir_name,file_name)
print(ful_path)
