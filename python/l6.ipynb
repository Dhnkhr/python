# %%
my_set={1,2,3,4,5,6}

ant_set=set([1,2,3,4,5])

print(type(my_set))
# Out:
# <class 'set'>

# %%
print(my_set)
# Out:
# {1, 2, 4, 5, 6, 7}

# %%
my_set.add(7)

# %%
my_set.remove(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 my_set.remove(3)
#
# KeyError: 3

# %%
my_set.discard(8)

# %%
my_set.pop()
my_set.clear()

# %%
print(10 in my_set)
# Out:
# False

# %%
set1={1,2,3,4,5,6,7,8}
set2={4,5,6,7,9}
union_set=set1.union(set2)

# %%
print(union_set)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
int_set=set1.intersection(set2)

# %%
print(int_set)
# Out:
# set()

# %%
set1.intersection_update(set2)
print(set1)
# Out:
# set()

# %%
print(set1.difference(set2))
# Out:
# {8, 1, 2, 3}

# %%
print(set1.symmetric_difference(set2))
# Out:
# {1, 2, 3, 8, 9}

# %%
set1={1,2,3}
set2={1,2,3,4}
print(set1.issubset(set2))
# Out:
# True

# %%
print(set1.issuperset(set2))
# Out:
# False

# %%
text="we are learning python"
words=text.split()
unq_wrds=set(words)
print(unq_wrds)
# Out:
# {'learning', 'are', 'we', 'python'}
