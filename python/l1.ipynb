# %%
name = "Adi"
Name = "Adi"

print(name)
print(Name)
# Out:
# Adi
# Adi

# %%
age = 30
if age > 30:
    print(age)

print(age)
# Out:
# 30

# %%
total=1+2+3+4+5+6+7+\
4+5+6
print (total)
# Out:
# 43

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
age = "32"
a=age
type(a)
# Out:
# str
